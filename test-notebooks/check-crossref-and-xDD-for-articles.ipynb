# %% [markdown]
# ### This notebook explores methods for relating articles of interest to literature databases
#
# Status: In Development
#
# Last Updated: 201904
#
# Summary: Our use cases often start with literature citation information,
# which can be variable in completeness.  This notebook explores options for
# connecting a csv based source of citation information to crossref and the
# University of Wisconsin-Madison xDD database.
#
# Inputs:  *csv of citation information
#     this uses data from USGS NAS that has varing completion of the following
#     variables: (internal id, authors, year, title, journal and doi )
#
# Contact: Daniel Wieferich (dwieferich@usgs.gov)

# %%
#Run this cell to ensure all packages and functions are available for 
#code that follows

import requests
import pandas as pd

def gdd_api(route, params):
    """Create list of docs mentioning a term of interest
    Parameters : see https://geodeepdive.org/api for more detail
    ----------
    routes : str of available api routes for xDD 
    params : str of key value pairs of paramaters:values separated by &
    """
    base_url = 'https://geodeepdive.org/api'
    search = (base_url + '/' + route + '?' + str(params))
    #print (search)
    try:
        r=requests.get(search)
        if r.status_code == 200 and 'success' in r.json():
            json_r = r.json()
            data = json_r['success']['data']
            return data
        elif r.status_code == 200:
            data = []
            return data
        else:
            raise Exception('xDD API returning: {}'.format(r.status_code))
    except Exception as e:
        raise Exception(e)
        
#DOI assignment
def clean_doi(doi_str):
    """Return DOI in common format without prefix of DOI:
    ----------
    Example output format: 10.1080/01411598708240781
    ----------
    Parameters : see https://geodeepdive.org/api for more detail
    ----------
    doi_str : input DOI 
    """
    if str(doi_str)!='nan':
        temp_doi = str((row.DOI).lower())
        temp_doi = temp_doi.replace('doi:', '')
        temp_doi = temp_doi.replace('doi ', '')
        if not temp_doi.startswith('doi') and not temp_doi.startswith('https:'):
            doi = temp_doi
            return (doi)
        else:
            doi = ''
            return (doi)
    else:
        doi = ''
        return (doi)

# %% [markdown]
# ##### Test for curiousity of seeing total list of journals included in xDD

# %%
journals = gdd_api('journals', 'all')

# %%
#List of journal names in xDD
journal = []
for j in journals:
    journal.append(j['journal'])
journal = list(set(journal))

print (str(len(journal)) + ' journals currently included')
journal
# Out:
# 5816 journals currently included
# ['',
#  'International Review of Psychiatry',
#  'Southeast European and Black Sea Studies',
#  'Journal of Free Radicals in Biology & Medicine',
#  'Annals of Oncology',
#  'Cultural and Social History',
#  'New Directions for Teaching and Learning',
#  'Journal of African Diaspora Archaeology and Heritage',
#  'Health Policy and Education',
#  'New Zealand Journal of Geology and Geophysics',
#  'Deep Sea Research Part B. Oceanographic Literature Review',
#  'Open-File ReportBibliography of reports resulting from U.S. Geological Survey scientific and technical cooperation with other countries, 1975 to June 1980',
#  'Journal of Geophysical Research: Oceans',
#  'Politics & Policy',
#  'Open-File ReportGeologic map of the Thoreau quadrangle, McKinley County, New Mexico',
#  'Evolutionary Anthropology: Issues, News, and Reviews',
#  'Flora oder Allgemeine Botanische Zeitung',
#  'Healthcare',
#  'EMC - Kinesiterapia - Medicina Física',
#  'Learning, Media and Technology',
#  'Sleep Medicine Clinics',
#  'EXPLORE: The Journal of Science and Healing',
#  'Mental Health Weekly',
#  'American Journal of Primatology',
#  'Respirology Case Reports',
#  'Journal of Clinical Forensic Medicine',
#  'Medicina Reproductiva y Embriología Clínica',
#  'Open-File ReportThermodynamic tabulations for selected phases in the system CaO-Al<sub>2</sub>O<sub>3</sub>-SiO<sub>2</sub>-H<sub>2</sub> at 101.325 kPa (1 atm) between 273.15 and 1800 K',
#  'International Journal of Applied Linguistics',
#  'Magnetic Resonance in Chemistry',
#  'Addiction Biology',
#  'Marine Ecology',
#  'Journal of Control and Decision',
#  'Biotechnology and Genetic Engineering Reviews',
#  'Cytometry Part A',
#  'Proceedings of the 15th World Conference on Earthquake Engineering (15WCEE), Lisbon, Portugal, September 24-28',
#  'European Surgery',
#  'Archiv der Pharmazie',
#  'Children & Society',
#  '3D Bioprinting and Nanotechnology in Tissue Engineering and Regenerative Medicine',
#  'Expert Review of Medical Devices',
#  'Polymer Electrolyte Membrane and Direct Methanol Fuel Cell Technology In Situ Characterization Techniques for Low Temperature Fuel Cells',
#  'Antarctic Map',
#  'Textbook of Family Medicine',
#  'International Journal of Coal Geology',
#  'Aquatic Insects',
#  'Acta Odontologica Scandinavica',
#  'Farmacéuticos de Atención Primaria',
#  'The International Archives of the Photogrammetry, Remote Sensing, and Spatial Information Sciences',
#  'World Banking Abstracts',
#  'The Journal of Mathematical Sociology',
#  'Africa Review',
#  'The New Bioethics',
#  'Dimensions of Behavior The Psychiatric Foundations of Medicine',
#  'Carcinogenesis',
#  'Communication Monographs',
#  'Journal of Convention & Event Tourism',
#  'Cell, Tissue, and Organ Cultures in Neurobiology',
#  'Journal of Accounting Research',
#  'Korean Journal of Urology',
#  'Eastern African Literary and Cultural Studies',
#  'Journal of the History of the Behavioral Sciences',
#  'European Environment',
#  'Journal of Land Use Science',
#  'Developments in Petroleum Science',
#  'Metabolic Phenotyping in Personalized and Public Healthcare',
#  'History and Anthropology',
#  'Immigrants & Minorities',
#  'Journal of Biopharmaceutical Statistics',
#  'Acta Oncologica',
#  'Fact SheetSpatial Data Transfer Standard (SDTS)',
#  'Archeological Papers of the American Anthropological Association',
#  'Toxicology Mechanisms and Methods',
#  'The Common Extremalities in Biology and Physics Maximum Energy Dissipation Principle in Chemistry, Biology, Physics and Evolution',
#  'Culture and Organization',
#  'ISPRS Journal of Photogrammetry and Remote Sensing',
#  'Boreas',
#  'Ethos',
#  'Emerging Trends in Computational Biology, Bioinformatics, and Systems Biology',
#  'Systems Engineering',
#  'Toxicity Assessment',
#  'Clinical Pharmacology & Therapeutics',
#  'Responsible Care A New Strategy for Pollution Prevention and Waste Reduction Through Environment Management',
#  'Planning Practice & Research',
#  'Jewish Culture and History',
#  'Journal of Marine Animals and their Ecology',
#  'Environmental Impact Assessment Review',
#  'General Hospital Psychiatry',
#  'Journal of Occupational Therapy, Schools, & Early Intervention',
#  'The Lancet Haematology',
#  'California Waterfowl',
#  'Infancy',
#  'EMC - Médecine',
#  'Cell Separation Methods and Selected Applications, Volume 3',
#  'Counselor Education and Supervision',
#  'Pharmaceutical Development and Technology',
#  'Tall Buildings The Proceedings of a Symposium on Tall Buildings with Particular Reference to Shear Wall Structures, Held in the Department of Civil Engineering, University of Southampton, April 1966',
#  'Small Wars & Insurgencies',
#  'Current Protocols in Neuroscience',
#  'Sexual Addiction & Compulsivity',
#  'International Journal of Robust and Nonlinear Control',
#  'Medicine, Conflict and Survival',
#  'Journal of Counselor Leadership and Advocacy',
#  'Bulletin des Sociétés Chimiques Belges',
#  'Wildlife Disease Association Newsletter',
#  'PET Clinics',
#  'Journal of Public Relations Research',
#  'Revue de Micropaléontologie',
#  'Theoretical Chemistry Periodicities in Chemistry and Biology',
#  'International Journal of Population Geography',
#  'Hearing, Balance and Communication',
#  'Ecosystem Health and Sustainability',
#  'Cancer Epidemiology',
#  'Foodservice Research International',
#  'Nations and Nationalism',
#  'New Scientist',
#  'Topics in Companion Animal Medicine',
#  'Social Development',
#  'Literature Compass',
#  'Open-File ReportGround-water flow, geochemistry, and effects of agricultural practices on nitrogen transport at study sites in the Piedmont and Coastal Plain physiographic provinces, Patuxent River basin, Maryland',
#  'Procedia Environmental Sciences',
#  'The Journal of Sexual Medicine',
#  'Petroleum Exploration and Development',
#  'Clematographic Techniques in Biology and Medicine',
#  'Zeitschrift für Pflanzenernährung, Düngung Bodenkunde',
#  'The Modern Law Review',
#  'Geophysical Research Letters',
#  'Eating Disorders',
#  'Open-File ReportIndex of surface-water records, part 9, Colorado River basin, to September 30, 1948',
#  'Angewandte Chemie',
#  'European Eating Disorders Review',
#  'Mathematical and Computer Modelling of Dynamical Systems',
#  'Professional Paper',
#  'Open-File ReportBase of fresh ground water (approximately 3,000 micromhos) in the San Joaquin Valley, California',
#  'Transfusion',
#  'Asia-Pacific Review',
#  'Equine Veterinary Journal',
#  'Journal of Maternal-Fetal and Neonatal Medicine',
#  'Substance Use & Misuse',
#  'Corporate Philanthropy Report',
#  'Expert Reviews in Molecular Medicine',
#  'Calculus Introductory Theory and Applications in Physical and Life Science',
#  'International Review of Finance',
#  'Platelets',
#  'Gaseous Hydrogen Embrittlement of Materials in Energy Technologies Mechanisms, Modelling and Future Developments',
#  'Entomological Science',
#  'Journal of the British Archaeological Association',
#  'Neurocomputing',
#  'Journal of Empirical Legal Studies',
#  'Medicine - Programa de Formación Médica Continuada Acreditado',
#  'Zeitschrift für Evidenz, Fortbildung und Qualität im Gesundheitswesen',
#  'Eukaryotic Cell Genetics',
#  'Journal of Experimental Zoology Part A: Ecological Genetics and Physiology',
#  'Photogrammetric Engineering and Remote Sensing',
#  'Journal of Evidence-Based Medicine',
#  'Open-File ReportSedimentary features of the Blackhawk Formation (Cretaceous) in the Sunnyside District, Carbon County, Utah',
#  'Disability and Rehabilitation',
#  'Journal of Biological Chemistry',
#  'International Journal of Housing Policy',
#  'Journal of Thrombosis and Haemostasis',
#  'Chemical Engineering & Technology',
#  'Autonomic and Autacoid Pharmacology',
#  'Open-File ReportThe National Geographic Names Data Base: Phase II instructions',
#  'Diaspora Studies',
#  'Chirality',
#  'Critical Quarterly',
#  'COPD: Journal of Chronic Obstructive Pulmonary Disease',
#  'Orthodontics & Craniofacial Research',
#  'British Journal of Psychotherapy',
#  'Genetical Research',
#  'Spatial Cognition & Computation',
#  'Applied Cognitive Psychology',
#  'Journal of Pain Research',
#  'The Membership Management Report',
#  'Journal of Sociolinguistics',
#  'Open-File ReportQuality of ground water in Idaho',
#  'Economic Notes',
#  'Juvenile Justice',
#  'Geriatrics & Gerontology International',
#  'Neurourology and Urodynamics',
#  'Weatherwise',
#  'Journal of Comparative Neurology',
#  'Japanese Economic Review',
#  'Dance Education in Practice',
#  'Forum for Social Economics',
#  'ASHE Higher Education Report',
#  'Quantitative Economics',
#  'Applied Clay Science',
#  'Cell Reproduction In honor of Daniel Mazia',
#  'Journal of Animal Breeding and Genetics',
#  'Asia Pacific Journal of Sport and Social Science',
#  'Zoo Biology',
#  'International Journal of Dairy Technology',
#  'Distinktion: Journal of Social Theory',
#  'Ratio',
#  'Revue Internationale de Sécurité Sociale',
#  'Land Degradation and Development',
#  'Smart Textiles for Medicine and Healthcare Materials, Systems and Applications',
#  'Oryx',
#  'Journal of Interlibrary Loan, Document Delivery & Electronic Reserve',
#  'World Art',
#  'Special Operations Journal',
#  'Australian Geographer',
#  'Open-File ReportGeologic map of the Casamero Lake quadrangle, McKinley County, New Mexico',
#  'Open-File ReportBedrock geologic map of the Warren quadrangle, Worcester, Hampden , and Hampshire Counties, south-central Massachusetts',
#  'Intelligent Systems in Accounting, Finance & Management',
#  'Disasters and Public Health Planning and Response',
#  'Proceedings of the Metallurgical Society of the Canadian Institute of Mining and Metallurgy Co-Sponsored by the Non-Ferrous Pyrometallurgy and Hydrometallurgy Sections of the Metallurgical Society of the CIM',
#  'Volcanica',
#  'Biological Conservation',
#  'Biological Rhythm Research',
#  'Advances in Water Pollution Research Proceedings of the Fourth International Conference held in Prague 1969',
#  'Pacing and Clinical Electrophysiology',
#  'Magnetic Resonance Materials in Physics, Biology and Medicine',
#  'International Journal of Andrology',
#  'Pharmacogenomics and Personalized Medicine',
#  'Early Medieval China',
#  'Biodemography and Social Biology',
#  'Plant Breeding',
#  'Cell and Tissue Based Molecular Pathology',
#  'Reproductive Biology',
#  'Canadian Foreign Policy Journal',
#  'Open-File ReportIndex of granitic rock masses in the state of Nevada',
#  'Immunology and Cell Biology',
#  'Journal of Agromedicine',
#  'Wildlife Society Bulletin',
#  'Current Therapeutic Research',
#  'Journal of Architecture and Urbanism',
#  'Zeitschrift für Tierphysiologie Tierernährung und Futtermittelkunde',
#  'British Poultry Science',
#  'Case Reports in Oncology',
#  'Journal of Statistical Theory and Practice',
#  'Komplementäre und Integrative Medizin',
#  'Logopedics Phoniatrics Vocology',
#  'Konsthistorisk tidskrift/Journal of Art History',
#  'B and T Cell Tumors',
#  'International Journal of Cultural Policy',
#  'Nutrition in Clinical Care',
#  'Opioid Peptides: Biology, Chemistry, and Genetics The Peptides: Analysis, Synthesis, Biology',
#  'Clinical Massage in the Healthcare Setting',
#  'Journal of Jewish Education',
#  'Journal of International Food & Agribusiness Marketing',
#  'Beton- und Stahlbetonbau',
#  'Aspects of Cell Regulation',
#  'Developmental Aspects of Oral Biology',
#  'System Dynamics Review',
#  'High Pressure Research',
#  'Physics and Chemistry of the Earth, Part B: Hydrology, Oceans and Atmosphere',
#  'Journal of the Science of Food and Agriculture',
#  'Journal for Maritime Research',
#  'Canadian Geographer / Le Géographe canadien',
#  'Economic Systems Research',
#  'Stress and Health',
#  'Journal of Evaluation in Clinical Practice',
#  'Land Degradation & Development',
#  'Sequential Analysis',
#  'Creative Industries Journal',
#  'Health Communication',
#  'Korean Diabetes Journal',
#  'Journal of Housing For the Elderly',
#  'Pathobiology of Cell Membranes Volume II',
#  'Image',
#  'The Information Society',
#  'Journal of the British Institute of Mental Handicap (APEX)',
#  'Conservation in Practice',
#  'Text and Performance Quarterly',
#  'International Journal of Rheumatic Diseases',
#  'Human Resource Management Journal',
#  'Communications in Algebra',
#  'The American Journal of Emergency Medicine',
#  'Metamorphosis Postembryonic Reprogramming of Gene Expression in Amphibian and Insect Cells',
#  'Clinical Otolaryngology',
#  'Biochemistry and Physiology of Plant Immunity',
#  'Critical Reviews in Biotechnology',
#  'Cartesian Tensors in Engineering Science The Commonwealth and International Library: Structures and Solid Body Mechanics Division',
#  'Small Animal Critical Care Medicine',
#  'International Journal of Applied Ceramic Technology',
#  'Journal of Structural Geology',
#  'Paedagogica Historica',
#  'Land Policy and Urban Growth Pergamon International Library of Science, Technology, Engineering and Social Studies',
#  'Journal of Applied Ichthyology',
#  'Operative Techniques in Sports Medicine',
#  'Introduction to Biological and Small Molecule Drug Research and Development Theory and Case Studies',
#  'Dialysis & Transplantation',
#  'CircularTungsten recycling in the United States in 2000',
#  'Investigations in Fish Control',
#  'Global Change Biology',
#  'Economics of Transition',
#  'Caribbean Quarterly',
#  'Special Care in Dentistry',
#  'Annual Review of Information Science and Technology',
#  'Japan Journal of Nursing Science',
#  'Cultural Anthropology',
#  'Yeast',
#  'Stahlbau',
#  'Computational Biology and Chemistry',
#  'ChemElectroChem',
#  'Journal of Genocide Research',
#  'Journal of Food Quality',
#  'International Journal of Philosophical Studies',
#  'Journal of Petroleum Science and Engineering',
#  'Monograph',
#  'Library & Information History',
#  'New Approaches in Cell Biology Proceedings of a Symposium Held At Imperial College, London, July 1958',
#  'Journal of Art & Design Education',
#  'International Insolvency Review',
#  'Irish Political Studies',
#  'Dutch Crossing',
#  'Studies in Conservation',
#  'Drug and Chemical Toxicology',
#  'Trends in Ecology & Evolution',
#  'Coastal Risk Management in a Changing Climate',
#  'The Journal of Peptide Research',
#  'Advances in Environmental Research',
#  'Studies in Gender and Sexuality',
#  'Restoration Ecology',
#  'Newsletter of the Wildlife Disease Association',
#  'Methods in Plant Molecular Biology',
#  'Pesticide Chemistry–3 Third International Congress of Pesticide Chemistry Including the Symposium on Dispersion Dynamics of Pollutants in the Environment',
#  'Spatial Statistics',
#  'Gaceta Sanitaria',
#  'Advances in Mining Science and Technology',
#  'Third Text',
#  'Palaeontology',
#  'Environmental Microbiology',
#  'Acta Chirurgica Belgica',
#  'Asia & the Pacific Policy Studies',
#  'Protein Engineering Design and Selection',
#  'International Journal of Quantum Chemistry',
#  'Water Research',
#  'Medical Teacher',
#  'JDDG: Journal der Deutschen Dermatologischen Gesellschaft',
#  'ChemistryOpen',
#  'Sikh Formations',
#  'Wiley Interdisciplinary Reviews: Computational Statistics',
#  'Global Environmental Change',
#  'Culture & Agriculture',
#  'Revista Médica del Hospital General de México',
#  'Performance & Instruction',
#  'British Journal of Psychology. General Section',
#  'New Directions for Higher Education',
#  'Conservation Biology',
#  'Japanese Journal of Cancer Research',
#  'Journal of Neurogenetics',
#  'Australian Economic Papers',
#  'Scientific Investigations Map',
#  'Journal of Hydraulic Research',
#  'The Brazilian Journal of Infectious Diseases',
#  'Chemical Zoology Arthropoda, Part A',
#  'Journal of Psychoactive Drugs',
#  'Journal of Electronic Resources Librarianship',
#  'Equine Neonatal Medicine A Case-Based Approach',
#  'Progress in Brain Research',
#  'Seafloor Geomorphology as Benthic Habitat GeoHAB Atlas of Seafloor Geomorphic Features and Benthic Habitats',
#  'Journal of Anatomy',
#  'International Journal of Climatology',
#  'Alcohol, Drugs, Genes and the Clinical Laboratory An Overview for Healthcare and Safety Professionals',
#  'Media Psychology',
#  'Food Additives & Contaminants: Part B',
#  'Ñawpa Pacha',
#  'Chinese Herbal Medicines Comparisons and Characteristics',
#  'Philosophical Issues',
#  'Open-File ReportDirectory of member organizations of the National Water Data Exchange (NAWDEX)',
#  'Differentiation and Immunology Symposia of the International Society for Cell Biology',
#  'International Journal of Play',
#  'Military Behavioral Health',
#  'International Journal of Psychoanalysis',
#  'Progress in Tourism and Hospitality Research',
#  'Calcium and Cell Function',
#  'Emerging Trends in Applications and Infrastructures for Computational Biology, Bioinformatics, and Systems Biology Systems and Applications',
#  'Journal of Traditional Chinese Medicine',
#  'Wind Energy',
#  'Zeitschrift für Tierpsychologie',
#  'Journal of Advanced Nursing',
#  'Australian Midwifery',
#  'Levant',
#  'Applied Earth Science',
#  'Comprehensive Natural Products II Chemistry and Biology',
#  'Bioethics',
#  'The Tide-Dominated Han River Delta, Korea Geomorphology, Sedimentology, and Stratigraphic Architecture',
#  'Letters in Applied Microbiology',
#  'Carbohydrate Chemistry, Biology and Medical Applications',
#  'North American Dialogue',
#  'Translational Sports Medicine',
#  'Fuzzy Sets and Systems',
#  'Connective Tissue Research',
#  'Encyclopedia of Animal Behavior',
#  'Headache: The Journal of Head and Face Pain',
#  'Practical Theology',
#  'Journal of Applied Statistics',
#  'Clinical Pediatric Emergency Medicine',
#  'Strategic Analysis',
#  'Public Health',
#  'The Journal of Rural Health',
#  'Azania: Archaeological Research in Africa',
#  'Ether Lipids Chemistry and Biology',
#  'Forest Ecology and Management',
#  'Noûs',
#  'Agriculture to Zoology Information Literacy in the Life Sciences',
#  'European Financial Management',
#  'Journal of Marital and Family Therapy',
#  'The Molecular and Hormonal Basis of Plant-Growth Regulation',
#  'Global Ecology and Biogeography',
#  'Financial Management',
#  'Genetic Expression in the Cell Cycle',
#  'Handbook of Waste Management and Co-Product Recovery in Food Processing Volume 2',
#  'Laboratory Exercises in Developmental Biology',
#  'Diabetes Care',
#  'Mount Sinai Journal of Medicine: A Journal of Translational and Personalized Medicine',
#  'Midwest Studies In Philosophy',
#  'Health Policy',
#  'Biomolecular Detection and Quantification',
#  'Traditional & Kampo Medicine',
#  'Biosynthesis and the Integration of Cell Metabolism',
#  'Journal of Adolescence',
#  'RISKNEWS',
#  'Porn Studies',
#  'The Lancet Neurology',
#  'IIE Transactions',
#  'Advances in Organic Geochemistry 1964 Proceedings of the International Meeting in Rueil–Malmaison, 1964',
#  'Advances in Cell Aging and Gerontology',
#  'Journal of Contingencies and Crisis Management',
#  "Jekel's Epidemiology, Biostatistics, Preventive Medicine, and Public Health",
#  'Canadian Journal of Forest Research',
#  'The European Journal of Finance',
#  'Journal of Environmental Science and Health, Part B: Pesticides, Food Contaminants, and Agricultural Wastes',
#  'Clinical Contraception',
#  'International Musculoskeletal Medicine',
#  'Dapim: Studies on the Holocaust',
#  'Oxford Journal of Archaeology',
#  'Current Opinion in Cell Biology',
#  'The Mekong Biophysical Environment of an International River Basin',
#  'Open-File ReportWater resources of the Blackstone River Basin, Massachusetts',
#  'Childhood in the Past',
#  'Quarterly Journal of Speech',
#  'Sedimentary Basins and Petroleum Geology of the Middle East',
#  'Animal Cell Technology Developments, Processes and Products',
#  'Geology',
#  'Biodiversity',
#  'European Journal of Inorganic Chemistry',
#  'Open-File ReportMovement and fate of creosote waste in ground water, Pensacola, Florida; U.S. Geological Survey toxic waste-ground-water contamination program',
#  'Medical and Healthcare Textiles',
#  'British Journal of Social and Clinical Psychology',
#  'Journal of International Wildlife Law & Policy',
#  'Housing and Society',
#  'Journal of the American Pharmaceutical Association (Practical Pharmacy ed.)',
#  'Biological Reviews of the Cambridge Philosophical Society',
#  'Nuclear Decommissioning, Waste Management, and Environmental Site Remediation',
#  'Agriculture and the Environment Papers presented at the International Conference, 10–13 November 1991',
#  'Journalism Practice',
#  'Hydrological Processes',
#  'Human Performance',
#  'Liver Cell Cancer',
#  'Circum-Pacific Map',
#  'Scandinavian Journal of Immunology',
#  'The Journal of Physiology',
#  'The Art of Palpatory Diagnosis in Oriental Medicine',
#  'Measurement in Physical Education and Exercise Science',
#  'Advances in Space Biology and Medicine',
#  'Forensic Science Policy & Management: An International Journal',
#  'Acta Oto-Laryngologica',
#  'Annals of Eugenics',
#  'Israel Journal of Chemistry',
#  'Journal of Social Work in End-Of-Life & Palliative Care',
#  'Neotropical Biodiversity',
#  'Acta Biotechnologica',
#  'American Review of Canadian Studies',
#  'Continuing Cardiology Education',
#  'Nephron Physiology',
#  'International Journal of Sustainable Engineering',
#  'disP - The Planning Review',
#  'Pediatric Obesity',
#  'Open-File ReportMagnitudes, nature, and effects of point and nonpoint discharges in the Chattahoochee River Basin, Atlanta to West Point Dam, Georgia',
#  'Italian Studies',
#  'Lubrication Science',
#  'Patient Preference and Adherence',
#  'Journal of Media Ethics',
#  'Zoonoses and Public Health',
#  'Laboratory Techniques in Biochemistry and Molecular Biology',
#  'Advances in Child Development and Behavior',
#  'Defence and Peace Economics',
#  'Journal of Mathematics and Music',
#  'Advances in Small Animal Medicine and Surgery',
#  'Immunobiology of the Complement System An Introduction for Research and Clinical Medicine',
#  'FEBS Journal',
#  'Journal of Medical Engineering & Technology',
#  'Open-File ReportWater levels and artesian pressures in observation wells in the United States, 1954, Part 6, Southwestern States and Hawaii',
#  'Molecular Biology of the Cell',
#  'Essentials of Stem Cell Biology',
#  'Resource Geology',
#  'Current Chemical Genomics',
#  'Open-File ReportFlood of April 1987 in Maine',
#  'African Geographical Review',
#  'Journal of Nonlinear Mathematical Physics',
#  'Prostaglandins and Medicine',
#  'The Journal of International Communication',
#  'Qualitative Research Reports in Communication',
#  "Comptes Rendus de l'Académie des Sciences - Series IIA - Earth and Planetary Science",
#  'Congress & the Presidency',
#  'Nordic Journal of Music Therapy',
#  'Acta Physiologica Scandinavica',
#  'Journal of the Linnean Society of London, Botany',
#  'Wiley Interdisciplinary Reviews: Energy and Environment',
#  'European Journal of Sport Science',
#  'Child Abuse Review',
#  'Mineral Commodities Summaries',
#  'Pediatric Allergy and Immunology',
#  'Anales de Pediatría (English Edition)',
#  'Human Fertility',
#  'New Functional Biomaterials for Medicine and Healthcare',
#  'Popular Communication',
#  'Bioprocess Engineering An Introductory Engineering and Life Science Approach',
#  'African Journal of Range & Forage Science',
#  'International Review of Neurobiology',
#  'Reviews in Religion & Theology',
#  'Autoradiography in Biology and Medicine',
#  'Vibrational Spectroscopy at High External Pressures The Diamond Anvil Cell',
#  'The Cell Volume III: Meiosis and Mitosis',
#  'Hepatology Research',
#  'Skandinavisches Archiv Für Physiologie',
#  'Journal of Motor Behavior',
#  'International Journal of Computational Fluid Dynamics',
#  'Journal of Sleep Research',
#  'Medicina interna. Secretos',
#  'Journal of Neuroscience Research',
#  'Cells and Tissues An Introduction to Histology and Cell Biology',
#  'Blood Cells, Molecules, and Diseases',
#  'Natural Selections',
#  'Oceanologica Acta',
#  'Wiley Interdisciplinary Reviews: RNA',
#  'Journal of Clinical Ultrasound',
#  'Optometry - Journal of the American Optometric Association',
#  'Journal für Praktische Chemie/Chemiker-Zeitung',
#  'Revista Clínica Española (English Edition)',
#  'Journal of Preventive Medicine and Public Health',
#  'Cell Synchrony Studies in Biosynthetic Regulation',
#  'Open-File ReportPotential hydrologic effects of ground-water withdrawals from the Dakota Aquifer, southwestern Kansas',
#  'Family and Consumer Sciences Research Journal',
#  'The Open Medical Informatics Journal',
#  'International Journal of Greenhouse Gas Control',
#  'Journal of Discrete Algorithms',
#  'International Journal of Microwave and Millimeter-Wave Computer-Aided Engineering',
#  'The International Spectator',
#  'Museum Anthropology',
#  'Journal of Engineering Design',
#  'Lasers in Surgery and Medicine',
#  'Advances in Psychology',
#  'International Journal of Drug Policy',
#  'Ground Water Monitoring and Remediation',
#  'European Journal of Philosophy',
#  'Pediatric Diabetes',
#  'Cell Biology of Physarum and Didymium Differentiation, Metabolism, and Methodology',
#  'Journal of Money, Credit and Banking',
#  'Aquatic Mammals',
#  'Journal of the Association for Information Science and Technology',
#  'Russian Studies in History',
#  'Annals of Gastroenterological Surgery',
#  'Sound Studies',
#  'Contemporary Accounting Research',
#  'Electromagnetic Biology and Medicine',
#  'Journal of Public Affairs',
#  'Bioelectromagnetics',
#  'Journal of Behavioral Finance',
#  'Journal of Hepato-Biliary-Pancreatic Sciences',
#  'Contemporary Music Review',
#  'Open-File ReportEvaluation of selected methods for determining streamflow during periods of ice effect',
#  'Acta hydrochimica et hydrobiologica',
#  'Occupational Therapy International',
#  'Pediatric Anesthesia',
#  'Clinics',
#  'Studies in Australasian Cinema',
#  'BioScience',
#  'Educational Theory',
#  'ChemBioChem',
#  'Addiction Research & Theory',
#  'Nineteenth-Century Contexts',
#  'BSHM Bulletin: Journal of the British Society for the History of Mathematics',
#  'Dynamics of Asymmetric Conflict',
#  'Evolution <html_ent glyph="@amp;" ascii="&amp;"/> Development',
#  'Plant Proteins Easter School in Agricultural Science',
#  'Functional Ecology',
#  'The Career Development Quarterly',
#  'Law <html_ent glyph="@amp;" ascii="&amp;"/> Social Inquiry',
#  'Information Systems',
#  'Journal of Public Health Dentistry',
#  'FEBS Letters',
#  'CPT: Pharmacometrics & Systems Pharmacology',
#  'Journal of Natural Gas Science and Engineering',
#  'Journal of Economics & Management Strategy',
#  'Allergy, Asthma & Immunology Research',
#  'Modern Theology',
#  'BulletinMap Projections: A Working Manual',
#  'Geografiska Annaler, Series A: Physical Geography',
#  'International Journal of Psychiatry in Clinical Practice',
#  'Conservation',
#  'Acta Genetica Sinica',
#  'Open-File ReportHydrogeology and results of injection tests at waste-injection test sites in Pinellas County, Florida',
#  'Communication Booknotes Quarterly',
#  'Comprehensive Reviews in Food Science and Food Safety',
#  'Journal of Legal Medicine',
#  'Cell of Immunoglobulin Synthesis',
#  'International Journal of Hygiene and Environmental Health',
#  'The Latin American Anthropology Review',
#  'European Journal of Immunogenetics',
#  'The American Journal on Addictions',
#  'Inquiry',
#  'Tel Aviv',
#  'R&D Management',
#  'Quarterly Journal of Experimental Physiology and Cognate Medical Sciences',
#  'Planning a Career in Biomedical and Life Sciences Making Informed Choices',
#  'Spatial and Spatio-temporal Epidemiology',
#  'Current Issues in Tourism',
#  'Expert Systems with Applications',
#  'Disability and Rehabilitation: Assistive Technology',
#  'Cell Differentiation',
#  'New Zealand Journal of Marine and Freshwater Research',
#  'Environmental Reviews',
#  'Journal of Difference Equations and Applications',
#  'Open-File ReportIdentification codes for organizations listed in computerized data systems of the U. S. Geological Survey',
#  'Biosystems',
#  'Continental Shelf Research',
#  'Ocean Tides Mathematical Models and Numerical Experiments',
#  'Geological Society of America Special Papers',
#  'Electronics and Communications in Japan',
#  'Fact Sheet',
#  'International Journal of Osteoarchaeology',
#  'Current Topics in Membranes',
#  'Applied Neuropsychology: Adult',
#  'Journal of Obstetrics and Gynaecology Research',
#  'The Open Neurology Journal',
#  'Journal of Aging Studies',
#  'Bioactive Materials in Medicine Design and Applications',
#  'Clinical and Experimental Dermatology',
#  'Studies in European Cinema',
#  'Northern History',
#  'Hematopoietic Stem Cell Transplantation in Clinical Practice',
#  'Journal of Dietary Supplements',
#  'Journal of the American Geriatrics Society',
#  'International Journal of Comparative and Applied Criminal Justice',
#  'Advances in Protein Chemistry and Structural Biology',
#  'Egyptian Journal of Petroleum',
#  'Environmental Science & Policy',
#  'American Business Law Journal',
#  'Environmental Archaeology',
#  'Asian Journal of Political Science',
#  'First Break',
#  'Religious Studies Review',
#  'Journal of Travel & Tourism Marketing',
#  'Systematic Entomology',
#  'Computer Physics Communications',
#  'Advances in Medical Sciences',
#  'La Contraception en Pratique De la situation clinique à la préscription',
#  'Journal of Graphic Novels and Comics',
#  'Computer Applications in Engineering Education',
#  'Reviews in Clinical and Experimental Hematology',
#  'Protist',
#  'Journal of Synthetic Lubrication',
#  'Cytogenetics of Cells in Culture',
#  'Learning Health Systems',
#  'Life Sciences',
#  'Advances in Water Resources',
#  'Journal of Industrial Ecology',
#  'British Journal of Haematology',
#  'Open-File ReportAeromagnetic map, Greenwood Lake quadrangle, Passaic County, New Jersey and Orange County, New York',
#  'Journal of the American Pharmaceutical Association (1996)',
#  'Open-File ReportChanges in flood response of the Red River of the North basin, North Dakota-Minnesota',
#  'Egyptian Informatics Journal',
#  'Trends in Cognitive Sciences',
#  'Communications in Numerical Methods in Engineering',
#  'ITBM-RBM News',
#  'Handbook of Polymer Applications in Medicine and Medical Devices',
#  'Expert Review of Endocrinology & Metabolism',
#  'Social Sciences in China',
#  'Acta Ophthalmologica Scandinavica',
#  'Cell Metabolism',
#  'Ultrasound in Obstetrics & Gynecology',
#  'Creativity and Innovation Management',
#  'Fatigue & Fracture of Engineering Materials & Structures',
#  'Journal of the Philosophy of Sport',
#  'Tratado de medicina de urgencias pediátricas',
#  'Principles and Applications of Rf/Microwave in Healthcare and Biosensing',
#  'Agricultural Meteorology',
#  'Genomic Medicine, Biomarkers, and Health Sciences',
#  'Frontiers of Bioorganic Chemistry and Molecular Biology Proceedings of the International Symposium on Frontiers of Bioorganic Chemistry and Molecular Biology, Moscow and Tashkent, USSR, 25 September–2 October 1978',
#  'Neuropsychiatric Disease and Treatment',
#  'Helicobacter',
#  'Tissue Barriers',
#  'Journal of Biologically Active Products from Nature',
#  'Adp-Ribosylation Reactions Biology and Medicine',
#  'Spatial Economic Analysis',
#  'Cell Regeneration',
#  'Journal of Building Performance Simulation',
#  'International Journal of Dermatology',
#  'Journal of Oral Pathology & Medicine',
#  'The Alkaloids: Chemistry and Biology',
#  'Therapeutic Apheresis and Dialysis',
#  'Introduction to Marine Micropaleontology',
#  'Thought: A Journal of Philosophy',
#  'Medicina Clínica',
#  'European Journal of Environmental and Civil Engineering',
#  'Helvetica Chimica Acta',
#  'Psychiatry',
#  'The European Journal of Contraception & Reproductive Health Care',
#  'Journal of Cosmetic Dermatology',
#  'Journal of Ethnicity in Substance Abuse',
#  'Proceedings of a Conference on Radiobiology at the Intra-Cellular Level This Conference Was Made Possible by Funds from the Division of Biology and Medicine of the Atomic Energy Commission',
#  'State-of-the-Art in Ecological Modelling Proceedings of the Conference on Ecological Modelling, Copenhagen, Denmark 28 August–2 September 1978',
#  'Advances in Free Radical Biology & Medicine',
#  'International Journal of Phytoremediation',
#  'Chronobiology International',
#  'Quality Engineering',
#  'Toxicology and Occupational Medicine Proceedings of the Tenth Inter-American Conference on Toxicology and Occupational Medicine, Key Biscayne (Miami), Florida, October 22–25, 1978',
#  'Communication, Culture & Critique',
#  'Geology and Engineering',
#  'The Art Book',
#  'Solar Cell Device Physics',
#  'European Journal of General Practice',
#  'Journal of Modern Italian Studies',
#  'Protein Science',
#  'Molecular Plant Pathology',
#  'Reproductive Biology of the Great Apes Comparative and Biomedical Perspectives',
#  'Asia-Pacific Journal of Financial Studies',
#  'Law & Society Review',
#  'Transactions of the Institute of British Geographers',
#  'International Journal of Developmental Disabilities',
#  'Fact SheetUS GeoData Digital Elevation Models',
#  'Journal of Educational Administration and History',
#  'Environmental Science and Technology',
#  'Journal of Neurochemistry',
#  'Waste Management & Research',
#  'International Journal of Radiation Applications and Instrumentation. Part B. Nuclear Medicine and Biology',
#  'Security Studies',
#  'Open-File ReportEvapotranspiration from areas of native vegetation in west-central Florida',
#  'Global Environmental Change Part B: Environmental Hazards',
#  'Biological Mass Spectrometry',
#  'European Journal of Neurology',
#  'Numerical Methods for Partial Differential Equations',
#  'Developmental Regulation Aspects of Cell Differentiation',
#  'Journal of Intervention and Statebuilding',
#  'Academic Pediatrics',
#  'Technical Communication Quarterly',
#  'Néphrologie & Thérapeutique',
#  'Clinical & Experimental Allergy Reviews',
#  'Biofilms in Infection Prevention and Control A Healthcare Handbook',
#  'Food, Culture & Society',
#  'Global Affairs',
#  'American Pharmacy',
#  'Cell Proliferation',
#  'Sociologia Ruralis',
#  'Database',
#  'Cell Growth and Cell Division',
#  'Open-File ReportMineral resources of the White Mountain Wilderness and adjacent areas, Lincoln County, New Mexico, with a section on aeromagnetic interpretation',
#  'Clinical Transplantation',
#  'Health Care for Women International',
#  'International Journal of Digital Earth',
#  'Alcohol and Abnormal Protein Biosynthesis Biochemical and Clinical',
#  'Developmental Science',
#  'Biochemical Systematics and Ecology',
#  'Herpetological Conservation and Biology',
#  'International Journal of General Systems',
#  'American Journal of Hematology',
#  'Ecography',
#  'Polymer Engineering & Science',
#  'Transport Policy',
#  'New Directions for Adult and Continuing Education',
#  'Planning Theory & Practice',
#  'Seminars in Surgical Oncology',
#  'Chinese Studies in History',
#  'Review of Income and Wealth',
#  'Deep Sea Research',
#  'Photochemistry and Photobiology',
#  'Brain Injury',
#  'Journal of Rock Mechanics and Geotechnical Engineering ',
#  'Journal of Clinical Child Psychology',
#  'Annals of Epidemiology',
#  'Mathematische Nachrichten',
#  'Gender & History',
#  'BioFactors',
#  'Basin Research',
#  'American Journal of Industrial Medicine',
#  'Bulletin of the London Mathematical Society',
#  'Die Unterrichtspraxis/Teaching German',
#  'Marine Geodesy',
#  'Journal of Terramechanics',
#  'Journal of Plastic Surgery and Hand Surgery',
#  'Physics and Chemistry of the Earth Progress Series, Volume 6',
#  'Decontamination in Hospitals and Healthcare',
#  'Journal of the Chinese Chemical Society',
#  'Applied Stochastic Models and Data Analysis',
#  'Journal of the Iowa Academy of Science',
#  'Japanese Psychological Research',
#  'International Journal of Advertising',
#  'Pigment Cell & Melanoma Research',
#  'Global Aquaculture Advocate',
#  'Contemporary Security Policy',
#  'Hydrometallurgy',
#  'Endocrine Research',
#  'Justice Quarterly',
#  'Plant/Operations Progress',
#  'Journal of Prosthodontics',
#  'Annals of Anthropological Practice',
#  'Asian Politics & Policy',
#  'Microsurgery',
#  'Molecular Medicine Today',
#  'Corporate Governance: An International Review',
#  'Molecular Systems Biology',
#  'Tellus',
#  'Proceedings of the International Symposium on Electrometallurigical Plant Practice The Metallurgical Society of CIM Hydrometallurgy Section',
#  'Quaternary Geochronology',
#  'Theology and Science',
#  'Orthopaedic Surgery',
#  'Introduction to Geological Maps and Structures Pergamon International Library of Science, Technology, Engineering and Social Studies',
#  'Veterinary Emergency Medicine Secrets',
#  'Prehospital Emergency Care',
#  'Current Protocols in Pharmacology',
#  'Journal of Wilderness Medicine',
#  'Physics and Chemistry of the Earth, Part C: Solar, Terrestrial & Planetary Science',
#  'Quarterly Journal of the Royal Meteorological Society',
#  'Expert Opinion on Drug Delivery',
#  'European Journal of Haematology',
#  'Plant Cell Biology From Astronomy to Zoology',
#  'The CSAS Bulletin',
#  'Nursing and Midwifery Portfolios',
#  'ASN NEURO',
#  'Clinical Obesity',
#  'Public Money and Management',
#  'Journal for the Study of Spirituality',
#  'Oil in Freshwater: Chemistry, Biology, Countermeasure Technology Proceedings of the Symposium of Oil Pollution in Freshwater, Edmonton, Alberta, Canada',
#  'Waste Management',
#  'Nuclear Medicine',
#  'Review of International Economics',
#  'Journal of Food Processing and Preservation',
#  'The Court Historian',
#  'Economic Inquiry',
#  'Occupational Therapy in Mental Health',
#  'MODSIM2011, 19th International Congress on Modelling and Simulation. Modelling and Simulation Society of Australia and New Zealand, December 2011',
#  'Chemical Vapor Deposition',
#  'Critical Reviews in Analytical Chemistry',
#  'Médecine Palliative : Soins de Support - Accompagnement - Éthique',
#  'Geophysical & Astrophysical Fluid Dynamics',
#  'Victims & Offenders',
#  'Australian Journal of Ecology',
#  'The Major Gifts Report',
#  'Mind, Culture, and Activity',
#  'Infectious Diseases',
#  'Clinical Critical Care Medicine',
#  'Energy Resources and Conservation Related to Built Environment Proceedings of the International Conference on Energy Resources and Conservation Related to Built Environment, December 7–12, 1980, Miami Beach, Florida',
#  'Egyptian Pediatric Association Gazette',
#  'Journal of the Proceedings of the Linnean Society of London. Botany',
#  'JCMS: Journal of Common Market Studies',
#  'Arid Land Research and Management',
#  'Statistica Neerlandica',
#  'Marine Geology of Korean Seas',
#  'Colorectal Disease',
#  'Wound Repair and Regeneration',
#  'Plant Ecology & Diversity',
#  'Health Expectations',
#  'Computer Methods in Applied Mechanics and Engineering',
#  'Register',
#  'Revista Española de Medicina Nuclear e Imagen Molecular',
#  'Cell Communication & Adhesion',
#  'Defence Studies',
#  'Polar Oceanography Chemistry, Biology, and Geology',
#  'The Open Neuroimaging Journal',
#  'Bulletin of the Association for Information Science and Technology',
#  'Journalism Studies',
#  'History of Education',
#  'Journal of Investigative and Clinical Dentistry',
#  'Geological Society of America Bulletin',
#  'Molecular Ecology Resources',
#  'A Materia Medica for Chinese Medicine Plants, minerals and animal products',
#  'Journal of the American Ceramic Society',
#  'The Journal of New Drugs',
#  'Ocular Immunology and Inflammation',
#  'Bioinformatics for Biomedical Science and Clinical Applications',
#  'Veterinary Medicine and Science',
#  'Acta Polymerica',
#  'Botany Letters',
#  'Clinical Toxicology',
#  'Optimization Methods and Software',
#  'Journal of Responsible Innovation',
#  'Drug Metabolism Reviews',
#  'Numerical Functional Analysis and Optimization',
#  'High Frequency',
#  'South Asian Popular Culture',
#  'The Mycoplasmas Cell Biology',
#  'Physics and Chemistry of the Earth, Part A: Solid Earth and Geodesy',
#  'Life Sciences and Space Research Proceedings of the Open Meeting of the Working Group on Space Biology of the Twenty-First Plenary Meeting of COSPAR, Innsbruck, Austria, 29 May–10 June 1978',
#  'Project Management Journal',
#  'Andrologia',
#  'Anthropology of Work Review',
#  'Tratado de Medicina Transfusional Perioperatoria 0',
#  'Earth and Planetary Science Letters',
#  'The Lancet Psychiatry',
#  'Canadian Journal of Biochemistry',
#  'Amyloid',
#  'Die Makromolekulare Chemie, Rapid Communications',
#  'Marine Ecology Progress Series',
#  'Public Money & Management',
#  'Zeitschrift für anorganische Chemie',
#  'Current Opinion in Structural Biology',
#  'Service Life Estimation and Extension of Civil Engineering Structures',
#  'Review of Urban & Regional Development Studies',
#  'Geophysical Prospecting',
#  'European Journal of Heart Failure',
#  'Oceanologia',
#  'Achievements in the Life Sciences',
#  'Critical Review',
#  'Open-File ReportCorrelation of paleostructure and sediment deposition in the Madison Limestone and associated rocks in parts of Montana, North Dakota, South Dakota, Wyoming, and Nebraska',
#  'Real-Time Imaging',
#  'Polar Human Biology The Proceedings of the SCAR/IUPS/IUBS Symposium on Human Biology and Medicine in the Antarctic',
#  'International Journal of Sexual Health',
#  'Ostrich',
#  'International Journal of Art Therapy',
#  'Liturgy',
#  'Molluscan Research',
#  'NeuroImage: Clinical',
#  'Women & Criminal Justice',
#  'Paleoceanography',
#  'Technometrics',
#  'Primitive Motile Systems in Cell Biology',
#  'Marine Chemistry',
#  'International Journal of Nuclear Medicine and Biology',
#  'African Journal of Marine Science',
#  'International Journal of Audiology',
#  'Journal of Vector Ecology',
#  'Optimization',
#  'Regeneration',
#  'Aggressive Behavior',
#  'Materialwissenschaft und Werkstofftechnik',
#  'Leisure Studies',
#  'Applicable Analysis',
#  'Contributions to Canadian Biology and Fisheries',
#  'Sports Coaching Review',
#  'Symbolic Interaction',
#  'Journal of Small Animal Practice',
#  'Legal Studies',
#  'Journal of Asian Natural Products Research',
#  'Theoretical Population Biology',
#  'Southeastern Archaeology',
#  'Biomarkers and Genomic Medicine',
#  'History and Technology',
#  'Dynamical Systems',
#  'Review of Political Economy',
#  'Latin American Politics and Society',
#  'Journal of Religious & Theological Information',
#  'Open-File ReportManmade organic compounds in the surface waters of the United States; a review of current understanding',
#  'African Zoology',
#  'Research Synthesis Methods',
#  'Hematological Oncology',
#  'Traffic',
#  'Scandinavian Journal of Food & Nutrition',
#  'Science and Technology for the Built Environment',
#  'The Journal of Finance',
#  'Journal of Economic Surveys',
#  'Environmental and Experimental Botany',
#  'International Journal of Auditing',
#  'Introduction to Quantum Mechanics in Chemistry, Materials Science, and Biology',
#  'New Directions for Institutional Research',
#  'The International History Review',
#  'Peripheral Vascular Surgery Tutorials in Postgraduate Medicine',
#  'Public Library Quarterly',
#  'Geodinamica Acta',
#  'Islam and Christian–Muslim Relations',
#  'Limnologica - Ecology and Management of Inland Waters',
#  'Internal Medicine Journal',
#  'The Leukemia-Lymphoma Cell Line FactsBook',
#  'Ecological Management & Restoration',
#  'Journal of Paediatrics and Child Health',
#  'Chemical Biology & Drug Design',
#  'Journal of Investigative Surgery',
#  'The Joint Commission Journal on Quality Improvement',
#  'Plant Tissue Culture and its Agricultural Applications Proceedings of Previous Easter Schools in Agricultural Science, Published by Butterworths, London',
#  'Developmental Cell',
#  'Pharmacotherapy: The Journal of Human Pharmacology and Drug Therapy',
#  'Electronic Notes in Discrete Mathematics',
#  'Studies in Surface Science and Catalysis',
#  'Contemporary Levant',
#  'The London Journal',
#  'Weed Biology and Management',
#  'Australian Journal of Maritime & Ocean Affairs',
#  'Journal of Applied Chemistry',
#  'City',
#  'The Evolution of the Metazoa International Series of Monographs on Pure and Applied Biology: Zoology, Vol. 16',
#  'Politics, Groups and Identities',
#  'British Educational Research Journal',
#  'Jewish Education',
#  'Canadian Journal of Latin American and Caribbean Studies / Revue canadienne des études latino-américaines et caraïbes',
#  'Social Policy & Administration',
#  'Environmental Progress & Sustainable Energy',
#  'Expert Review of Proteomics',
#  'Modern Applications of Plant Biotechnology in Pharmaceutical Sciences',
#  'Journal of Applied Chemistry and Biotechnology',
#  'Clinical Liver Disease',
#  'Identities',
#  'Arboricultural Journal',
#  'Business Strategy Review',
#  'Journal of Futures Markets',
#  'International Journal of Energy Research',
#  'Geocarto International',
#  ...]

# %%
#Import data into a pandas dataframe and print field names
file_name = '20190326_NAS_journal_articles.csv'
df = pd.read_csv(file_name, sep=',')
df.columns
# Out:
# Index(['refnum', 'author', 'publication_year', 'title', 'journal_name',
#        'volume', 'issue', 'pages', 'specimen_data_entered', 'key_words',
#        'DOI'],
#       dtype='object')

# %% [markdown]
# Initial Testing of Crossref suggests using a threshold of 93 to
# ensure correct matches, more testing with NAS team is being conducted.
#
# Notes: This cell took a few hours to run on the 10,000 article databse, it
# was intentionally throttled to ensure within crossrefs suggested
# load. (0.15 second sleep between iterations)
#
# This effort will eventually feed into the Biogeographic Information System's Research Reference Library efforts and database

# %%
#using the pybis package from https://github.com/usgs-bis/pybis
from pybis.rrl import ResearchReferenceLibrary as rrl
import time

crossref_info = []
for row in df.itertuples():
    refnum = row.refnum
    title_nas = row.title
    doi_nas = clean_doi(row.DOI)
    short_citation = (str(row.author)+'. '+str(row.publication_year)+'. '+str(title_nas)+' '+str(row.journal_name) + str(doi_nas))
    try:
        crossref_results = rrl.lookup_crossref(short_citation, threshold=70)
        if crossref_results['Success'] is True:
            if 'DOI' in crossref_results['Record']:
                doi = crossref_results['Record']['DOI']
            if 'title' in crossref_results['Record']:
                title = crossref_results['Record']['title'][0]
            if 'Score' in crossref_results:
                score = crossref_results['Score']
            crossref_info.append({'refnum': refnum, 'short_citation': short_citation, 'cr_title':title, 'title_nas':title_nas, 'cr_doi':doi, 'doi_nas': doi_nas, 'score':score, 'crossref':crossref_results})
        else:
            crossref_info.append({'refnum': refnum, 'short_citation': short_citation, 'cr_title':'', 'title_nas':title_nas, 'cr_doi':'', 'doi_nas': doi_nas, 'score':'', 'crossref':'False'})

    except:
        crossref_info.append({'refnum': refnum, 'short_citation': short_citation, 'cr_title':'', 'title_nas':title_nas, 'cr_doi':'', 'doi_nas': doi_nas, 'score':'', 'crossref':'failed'})
        continue
    print (refnum)
    
    time.sleep(0.15)
    
cross_ref_df=pd.DataFrame(crossref_info)
cross_ref_df.to_csv("./crossref_nas_df.csv", sep=',', index=False)

# %%
#Until database is in place, use this line so we don't have to 
#rerun crossref cell above
crossref_df = pd.read_csv("crossref_nas_df.csv", sep=',')

# %%
#Temporary fix to code, remove cr_title where crossref=='False' and crossref=='failed'
crossref_df.loc[crossref_df.crossref =='False', 'cr_title']= ''
crossref_df.loc[crossref_df.crossref =='failed', 'cr_title']= ''

# %%
crossref_df.tail(5)
# Out:
#                               cr_doi  \
# 10654  10.1080/02705060.2003.9664007
# 10655   10.1371/journal.pone.0048233
# 10656   10.1371/journal.pone.0079516
# 10657                            NaN
# 10658                            NaN
#
#                                                 cr_title  \
# 10654  The Introduction of an Invasive Snail (Melanoi...
# 10655  Phylogeny and Evolutionary Patterns in the Dwa...
# 10656  Sequencing and De Novo Assembly of the Asian C...
# 10657
# 10658
#
#                                                 crossref  \
# 10654  {'Success': True, 'Date Checked': '2019-04-03T...
# 10655  {'Success': True, 'Date Checked': '2019-04-03T...
# 10656  {'Success': True, 'Date Checked': '2019-04-03T...
# 10657                                              False
# 10658                                              False
#
#                             doi_nas  refnum      score  \
# 10654                           NaN   32622  104.05482
# 10655  10.1371/journal.pone.0048233   32623  126.86783
# 10656                           NaN   32629  121.16053
# 10657                           NaN   32630        NaN
# 10658                           NaN   32632        NaN
#
#                                           short_citation  \
# 10654  Rader, R.B., M.C. Belk, and M.J. Keleher. 2003...
# 10655  Pedraza-Lara, C., I. Doadrio, J.W. Breinholt, ...
# 10656  Chen, H., J. Zha, X. Liang, J. Bu, M. Wang, an...
# 10657  Ladd, H.L.A., and D.L. Rogowski. 2012. Egg pre...
# 10658  Ituarte, C.F.. 1994. <em>Corbicula</em> and <e...
#
#                                                title_nas
# 10654  The Introduction of an Invasive Snail (Melanoi...
# 10655  Phylogeny and evolutionary patterns in the dwa...
# 10656  Sequencing and De Novo Assembly of the Asian C...
# 10657  Egg predation and parasite prevalence in the i...
# 10658  <em>Corbicula</em> and <em>Neocorbicula</em> (...

# %%
#Grab subset for testing of xDD next steps
cr_25_df = crossref_df.iloc[-10:]
cr_25_df.head(25)

# %% [markdown]
# #### Initial test of linking article information to xDD ids (when article is present in xDD)
#
# Logic behind linkage to xDD
#
# 1) If DOI from Crossref (cr_doi) is available use to search/relate to xDD
#
#     a) no doi relation, try matching title
#
#     b) no title match, try title_like parameter
#
# 2) If cr_doi is not available try using source data DOI
#
#     a) no doi relation, try matching title
#
#     b) no title match, try title_like parameter
#
# 3) If DOI is not available try using title to search/relate to xDD
#
#     a) no title match, try title_like parameter
#
# In this exercise the title_like matching produced false matches more times than not, we need to look into this more to see if it is worth including this into the future

# %%
import requests

rrl_gdd = []
for row in crossref_df.itertuples():
    try:
        refnum = row.refnum
        title_nas = row.title_nas
        
        #remove html tags/formating
        title_nas = title_nas.replace("</em>", "")
        title_nas = title_nas.replace("<em>","")
        
        #print (refnum)
        route = 'articles'
        #NAS has DOI, yes/no
        if row.score and row.cr_doi and row.score>=93 and str(row.cr_doi)!='nan':
            param = 'max=1&doi='+str(row.cr_doi)
            gdd_data = gdd_api(route, param)
            if gdd_data:
                gdd_id = gdd_data[0]['_gddid']
                rrl_gdd.append({'refnum': refnum, 'relation': 'doi_match', 'gdd_id':gdd_id, 'param':param})
            elif row.title_nas and str(row.title_nas) != '' and not title_nas.startswith("(") :
                param = 'max=1&title='+ title_nas
                gdd_data = gdd_api(route, param)
                #Does title return successful match
                if gdd_data:
                    gdd_id = gdd_data[0]['_gddid']
                    rrl_gdd.append({'refnum': refnum, 'relation': 'title_match', 'gdd_id':gdd_id, 'param':param})
                else:
                    param = 'max=1&title_like=' + title_nas
                    gdd_data = gdd_api(route, param)
                    if gdd_data:
                        gdd_id = gdd_data[0]['_gddid']
                        rrl_gdd.append({'refnum': refnum, 'relation': 'title_like', 'gdd_id':gdd_id, 'param':param})
                    else:
                        rrl_gdd.append({'refnum': refnum, 'relation': 'no_match', 'gdd_id':gdd_id, 'param':''})
        elif row.doi_nas and str(row.doi_nas)!='nan':
            param = 'max=1&doi='+str(row.doi_nas)
            gdd_data = gdd_api(route, param)
            if gdd_data:
                gdd_id = gdd_data[0]['_gddid']
                rrl_gdd.append({'refnum': refnum, 'relation': 'doi_match', 'gdd_id':gdd_id, 'param':param})
            elif row.title_nas and str(row.title_nas) != '' and not title_nas.startswith("(") :
                param = 'max=1&title='+ title_nas
                gdd_data = gdd_api(route, param)
                #Does title return successful match
                if gdd_data:
                    gdd_id = gdd_data[0]['_gddid']
                    rrl_gdd.append({'refnum': refnum, 'relation': 'title_match', 'gdd_id':gdd_id, 'param':param})
                else:
                    param = 'max=1&title_like=' + title_nas
                    gdd_data = gdd_api(route, param)
                    if gdd_data:
                        gdd_id = gdd_data[0]['_gddid']
                        rrl_gdd.append({'refnum': refnum, 'relation': 'title_like', 'gdd_id':gdd_id, 'param':param})
                    else:
                        rrl_gdd.append({'refnum': refnum, 'relation': 'no_match', 'gdd_id':gdd_id, 'param':''})
        elif row.title_nas and str(row.title_nas) != ''and not title_nas.startswith("("):
            param = 'max=1&title='+ title_nas
            gdd_data = gdd_api(route, param)
            #Does title return successful match
            if gdd_data:
                gdd_id = gdd_data[0]['_gddid']
                rrl_gdd.append({'refnum': refnum, 'relation': 'title_match', 'gdd_id':gdd_id, 'param':param})
            else:
                param = 'max=1&title_like=' + title_nas
                gdd_data = gdd_api(route, param)
                if gdd_data:
                    gdd_id = gdd_data[0]['_gddid']
                    rrl_gdd.append({'refnum': refnum, 'relation': 'title_like', 'gdd_id':gdd_id, 'param':param})
                else:
                    rrl_gdd.append({'refnum': refnum, 'relation': 'no_match', 'gdd_id':gdd_id, 'param':''})
        else:
            rrl_gdd.append({'refnum': refnum, 'relation': 'no_match', 'gdd_id':gdd_id, 'param':''})
            #print ('else:' + str(refnum))
    except:
            rrl_gdd.append({'refnum': refnum, 'relation': 'failed exception', 'gdd_id':''})
            print ('try:' + str(refnum)+':  '+param)
            continue
        
rrl_xdd_df = pd.DataFrame(rrl_gdd)
rrl_xdd_df.to_csv("./rrl_xdd_df.csv", sep=',', index=False)
# Out:
# try:12249:  max=1&title_like=Accumulation of trace elements, pesticides, and polychlorinated biphenyls in sediments and the clam Corbicula manilensis of the Apalachicola River, Florida.
# try:12250:  max=1&title=Genetic studies of Asiatic clams, Corbicula, in Thailand: allozymes of 21 nominal species are identical.
# try:12251:  max=1&title=Comparative shell microstructure of North American Corbicula (Bivalvia: Sphaeriacea).
# try:12252:  max=1&doi=10.2307/3226519
# try:12253:  max=1&title=Cipangopaludina chinensis (Gastropoda: Viviparidae) in North America, review and update.
# try:12254:  max=1&title=Thousands of living European snails sold as fish bait in state of Ohio.
# try:12255:  max=1&title=Snails on migratory birds.
# try:12256:  max=1&title=Corbicula fluminea (M&uuml;ller) in Louisiana.
# try:13003:  max=1&doi=10.1093/icb/37.6.621
# try:13004:  max=1&title=Invasion pressure to a ballast-flooded estuary and assessment of inoculant survival.
# try:13216:  max=1&title=The effects of temperature, body size, and hydration state on the terrestrial locomotion of the crayfish Orconectes rusticus.
# try:13217:  max=1&doi=10.1111/j.0014-3820.2001.tb00635.x
# try:13218:  max=1&doi=10.1080/02705060.1998.9663589
# try:13219:  max=1&title=The presence of the Asiatic clam, Corbicula sp., from Lake Superior.
# try:16903:  max=1&title_like=The functional role of native freshwater mussels in the fluvial benthic environment.
# try:16904:  max=1&title=Zoogeography of North American Unionaceae (Mollusca: Bivalvia) north of the maximum Pleistocene glaciation.
# try:16905:  max=1&doi=10.1046/j.1365-294x.1999.00784.x
# try:17418:  max=1&title_like=About some freshwater centric diatoms from Argentina.
# try:17419:  max=1&doi=10.1007/bf00028002
# try:17420:  max=1&title=Morphology and taxonomy of the centric diatom Cyclotella atomus.
# try:28818:  max=1&title_like=Aquatic invasive species and emerging infectious disease threats: a one health perspective.
# try:32280:  max=1&title_like=A new variety of Cyclotella atomus from Tokyo Bay, Japan: C. atomus var. marina var. nov
# try:32281:  max=1&title_like=A new variety of Cyclotella atomus from Tokyo Bay, Japan: C. atomus var. marina var. nov

# %%
rrl_xdd_df = pd.read_csv("./rrl_xdd_df.csv", sep=',')
rrl_xdd_df.tail(25)
# Out:
#                          gdd_id  \
# 10634  5ac253b2cf58f132fd5c93da
# 10635  56b98663cf58f14c238d4b94
# 10636  57b17ebbcf58f1442ca068cf
# 10637  58c9abe3cf58f128a153cf46
# 10638  571bcb24cf58f15b2a782a1f
# 10639  57a5b2cecf58f17c163722fc
# 10640  57a22a2dcf58f13b8c118fc9
# 10641  56cf9bbccf58f1b14db25bdf
# 10642  572cc56bcf58f12aa3017605
# 10643  57b17ebbcf58f1442ca068cf
# 10644  576c0ae2642f8829d3759f2d
# 10645  5714d035cf58f14cea37e88b
# 10646  5712ae66cf58f1589a2a8bee
# 10647  596221e8cf58f15ac87a003a
# 10648  57a83881cf58f16cca187e66
# 10649  56b2e378cf58f14c238d2482
# 10650  595cd4e1cf58f119b6b27c4b
# 10651  5c44b7531faed65548935065
# 10652  5c8f65574e85ba2e7cbfef07
# 10653  58967212cf58f161d04cea94
# 10654  5c3d53f71faed655488cc10b
# 10655  576eecd3642f883f1882bc8e
# 10656  5723a0ed642f88867bc44efb
# 10657  576b9255cf58f112aa4e5b69
# 10658  572d639ccf58f16364fd0247
#
#                                                    param  refnum    relation
# 10634  max=1&title_like=A successful crayfish invader...   32589  title_like
# 10635  max=1&title_like=An updated classification of ...   32590  title_like
# 10636                          max=1&doi=10.1139/f08-162   32591   doi_match
# 10637  max=1&title_like=The spiny-cheek crayfish, Orc...   32592  title_like
# 10638  max=1&title_like=Invasive crayfish and crayfis...   32594  title_like
# 10639  max=1&title_like=Invasive non-indigenous crayf...   32595  title_like
# 10640  max=1&title_like=Crayfish Plague agent detecte...   32596  title_like
# 10641  max=1&title_like=The diet of the spiny-cheek c...   32598  title_like
# 10642  max=1&title_like=Understanding invasion succes...   32599  title_like
# 10643  max=1&title_like=Aggressive interactions and c...   32600  title_like
# 10644             max=1&doi=10.1371/journal.pone.0157174   32604   doi_match
# 10645         max=1&doi=10.1111/j.1365-2427.2007.01741.x   32605   doi_match
# 10646                         max=1&doi=10.1002/ece3.903   32606   doi_match
# 10647  max=1&title_like=The bioenergentic consequence...   32607  title_like
# 10648  max=1&title_like=Phylogeography and population...   32608  title_like
# 10649  max=1&title_like=Food habits of diving ducks i...   32609  title_like
# 10650  max=1&title_like=Sources of Bighead Carp and S...   32613  title_like
# 10651  max=1&title_like=Minutes of the Conchological ...   32615  title_like
# 10652  max=1&title_like=Invasion genetics from eDNA a...   32619  title_like
# 10653  max=1&title_like=An inconvenient monophyly: an...   32621  title_like
# 10654            max=1&doi=10.1080/02705060.2003.9664007   32622   doi_match
# 10655             max=1&doi=10.1371/journal.pone.0048233   32623   doi_match
# 10656  max=1&title_like=Sequencing and De Novo Assemb...   32629  title_like
# 10657  max=1&title_like=Egg predation and parasite pr...   32630  title_like
# 10658  max=1&title_like=Corbicula and Neocorbicula (B...   32632  title_like

# %%
#Need to alter this but gives basic stats on number matched each way
group_df = rrl_xdd_df.groupby(['relation']).count()
#group_df.reset_index(inplace=True)

# %%
group_df
# Out:
#                   gdd_id  param  refnum
# relation
# doi_match           1751   1751    1751
# failed exception      23      0      23
# no_match             169    169     169
# title_like          8094   8094    8094
# title_match          622    622     622
